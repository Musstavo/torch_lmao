# %%
import monai
import torch
import os
from glob import glob
from monai.transforms import (
    
)
# Out:
#   Cell In[2], line 5
#     from monai.transforms import (
#                                   ^
# SyntaxError: incomplete input
